# %%
import requests
import re
from pyphy import pyphy

import pandas as pd
import numpy as np

# %%
virushostdb = pd.read_csv('virushostdb/virushostdb.tsv', sep="\t")
virushostdb.head()

virus_host_connection = virushostdb[virushostdb["host tax id"].notnull()][["virus tax id", "host tax id", "virus name"]]

virus_host_connection["host tax id"] = virus_host_connection["host tax id"].astype("int32")

# %%
brite_virus = "https://rest.kegg.jp/get/br:br08620"

# %%
detail = requests.get(brite_virus).text

with open("brite/brite_virus.txt", "w") as output:
    output.write(detail)

# %%
rx_entry = re.compile(r'(\d+)\s+(.+)\[TAX:(\d+)\]')

# %%
taxid_name = {}

virus_type = ""

for line in detail.split("\n"):

        
    search_entry = rx_entry.search(line)
    #print (line)
    if search_entry:
        name = search_entry.group(2)
        name = re.sub(r'\[.+\]', '', name).strip()

        #print (f"{search_entry.group(1)},{name}")
        taxid_name[int(search_entry.group(1))] = name

# %%
taxid_name
# Out:
# {12639: 'Duck hepatitis B virus',
#  259931: "Ross's goose hepatitis B virus",
#  259898: 'Sheldgoose hepatitis B virus',
#  89623: 'Snow goose hepatitis B virus',
#  28300: 'Heron hepatitis B virus',
#  1128118: 'Parrot hepatitis B virus',
#  2018685: 'Tinamou hepatitis B virus',
#  2169919: 'Tibetan frog hepatitis B virus',
#  2169918: 'Bluegill hepatitis B virus',
#  2163996: 'Capuchin monkey hepatitis B virus',
#  2107574: 'Domestic cat hepadnavirus',
#  10406: 'Ground squirrel hepatitis virus',
#  10407: 'Hepatitis B virus',
#  2050037: 'Long-fingered bat hepatitis B virus',
#  2049933: 'Pomona bat hepatitis B virus',
#  1508710: 'Roundleaf bat hepatitis B virus',
#  1508711: 'Horseshoe bat hepatitis B virus',
#  1508712: 'Tent-making bat hepatitis B virus',
#  35269: 'Woodchuck hepatitis virus',
#  68416: 'Woolly monkey hepatitis B virus',
#  1690672: 'White sucker hepatitis B virus',
#  1512278: 'Aglaonema bacilliform virus',
#  328670: 'Banana streak GF virus',
#  1016853: 'Banana streak IM virus',
#  1476909: 'Banana streak MY virus',
#  328671: 'Banana streak OL virus',
#  1016854: 'Banana streak UA virus',
#  1016855: 'Banana streak UI virus',
#  1016856: 'Banana streak UL virus',
#  1016857: 'Banana streak UM virus',
#  1411991: 'Banana streak VN virus',
#  2057979: 'Birch leaf roll-associated virus',
#  2560349: 'Blackberry virus F',
#  263892: 'Bougainvillea chlorotic vein banding virus',
#  1940252: 'Cacao mild mosaic virus',
#  1960255: 'Cacao swollen shoot CD virus',
#  2056879: 'Cacao swollen shoot CE virus',
#  2056883: 'Cacao swollen shoot Ghana M virus',
#  2056884: 'Cacao swollen shoot Ghana N virus',
#  2056885: 'Cacao swollen shoot Ghana Q virus',
#  1960254: 'Cacao swollen shoot Togo A virus',
#  31559: 'Cacao swollen shoot virus',
#  2169726: 'Cacao yellow vein banding virus',
#  2697535: 'Camellia lemon glow virus',
#  2560371: 'Canna yellow mottle associated virus',
#  419782: 'Canna yellow mottle virus',
#  174178: 'Citrus yellow mosaic virus',
#  10653: 'Commelina yellow mottle virus',
#  549205: 'Cycad leaf necrosis virus',
#  1619899: 'Dioscorea bacilliform AL virus',
#  2169727: 'Dioscorea bacilliform RT virus 1',
#  2011125: 'Dioscorea bacilliform RT virus 2',
#  2169728: 'Dioscorea bacilliform TR virus',
#  380669: 'Dracaena mottle virus',
#  1034096: 'Fig badnavirus 1',
#  157270: 'Gooseberry vein banding associated virus',
#  1471299: 'Grapevine Roditis leaf discoloration-associated virus',
#  2052838: 'Grapevine badnavirus 1',
#  1050407: 'Grapevine vein clearing virus',
#  2731270: 'Ivy ringspot-associated virus',
#  2020956: 'Jujube mosaic-associated virus',
#  218387: 'Kalanchoe top-spotting virus',
#  1227557: 'Mulberry badnavirus 1',
#  1505530: 'Pagoda yellow mosaic associated virus',
#  2033633: 'Pineapple bacilliform CO virus',
#  2034763: 'Pineapple bacilliform ER virus',
#  262957: 'Piper yellow mottle virus',
#  2528410: 'Polyscias mosaic virus',
#  198310: 'Rubus yellow net virus',
#  2169729: 'Schefflera ringspot virus',
#  157271: 'Spiraea yellow leafspot virus',
#  1960252: 'Sugarcane bacilliform Guadeloupe A virus',
#  1960253: 'Sugarcane bacilliform Guadeloupe D virus',
#  362398: 'Sugarcane bacilliform IM virus',
#  362399: 'Sugarcane bacilliform MO virus',
#  2034762: 'Sweet potato pakakuy virus',
#  1634914: 'Taro bacilliform CH virus',
#  178354: 'Taro bacilliform virus',
#  1973265: 'Wisteria badnavirus 1',
#  1561150: 'Yacon necrotic mottle virus',
#  1016852: 'Banana streak CA virus',
#  334778: 'Banana streak virus Acuminata Yunnan',
#  2056878: 'Cacao Bacilliform SriLanka Virus',
#  2056880: 'Cacao swollen shoot Ghana J virus',
#  2056881: 'Cacao swollen shoot Ghana K virus',
#  2056882: 'Cacao swollen shoot Ghana L virus',
#  2056886: 'Cacao swollen shoot Ghana R virus',
#  52996: 'Dioscorea bacilliform virus',
#  1459800: 'Hibiscus bacilliform virus GD1',
#  671126: 'Pelargonium vein banding virus',
#  647294: 'Sweet potato badnavirus B',
#  1808970: 'Angelica bushy stunt virus',
#  1711685: 'Atractylodes mild mottle virus',
#  10640: 'Carnation etched ring virus',
#  10641: 'Cauliflower mosaic virus',
#  213888: 'Dahlia mosaic virus',
#  10649: 'Figwort mosaic virus',
#  264076: 'Horseradish latent virus',
#  515320: 'Lamium leaf distortion virus',
#  194445: 'Mirabilis mosaic virus',
#  1221449: 'Soybean Putnam virus',
#  47903: 'Strawberry vein banding virus',
#  515444: 'Eupatorium vein clearing virus',
#  38062: 'Cassava vein mosaic virus',
#  2713640: 'Epiphyllum virus 4',
#  930168: 'Sweet potato collusive virus',
#  2303485: 'Dioscorea nummularia-associated virus',
#  59504: 'Petunia vein clearing virus',
#  1213588: 'Rose yellow vein virus',
#  587370: 'Rudbeckia flower distortion virus',
#  995049: 'Sweet potato vein clearing virus',
#  107324: 'Tobacco vein clearing virus',
#  172220: 'Blueberry red ringspot virus',
#  175814: 'Cestrum yellow leaf curling virus',
#  35593: 'Peanut chlorotic streak virus',
#  10651: 'Soybean chlorotic mottle virus',
#  1848040: 'Water chestnut soymovirus 1',
#  10654: 'Rice tungro bacilliform virus',
#  1751715: 'Blueberry fruit drop associated virus',
#  2267679: 'Pinus nigra virus 1',
#  2083181: 'Trichoplusia ni TED virus',
#  2052899: 'Cladosporium fulvum T-1 virus',
#  11946: 'Avian leukemia virus',
#  363745: 'Avian leukosis virus - RSA',
#  11866: 'Avian myeloblastosis virus',
#  11878: 'Avian sarcoma virus CT10',
#  11885: 'Fujinami sarcoma virus',
#  11886: 'Rous sarcoma virus',
#  354090: 'UR2 sarcoma virus',
#  11884: 'Y73 sarcoma virus',
#  11958: 'Avian carcinoma virus',
#  11867: 'Avian myelocytomatosis virus',
#  11746: 'Jaagsiekte sheep retrovirus',
#  240594: 'Endogenous langur type D retrovirus PO-1-Lu',
#  11855: 'Mason-Pfizer monkey virus',
#  11757: 'Mouse mammary tumor virus',
#  11856: 'Squirrel monkey retrovirus',
#  1822365: 'Bovine retrovirus CH15',
#  1622024: 'Desmodus rotundus endogenous retrovirus',
#  239365: 'Enzootic nasal tumour virus of goats',
#  69576: 'Ovine enzootic nasal tumor virus',
#  723802: 'Simian retrovirus 4',
#  1904439: 'Simian retrovirus 8',
#  11901: 'Bovine leukemia virus',
#  194440: 'Primate T-lymphotropic virus 1',
#  11908: 'Human T-cell leukemia virus type I',
#  11909: 'Human T-lymphotropic virus 2',
#  33748: 'Simian T-lymphotropic virus 2',
#  194443: 'Primate T-lymphotropic virus 3',
#  318279: 'Human T-lymphotropic virus 4',
#  481147: 'Simian T-cell lymphotropic virus 6',
#  39720: 'Walleye dermal sarcoma virus',
#  64462: 'Walleye epidermal hyperplasia virus 1',
#  64461: 'Walleye epidermal hyperplasia virus 2',
#  353768: 'Chick syncytial virus',
#  11768: 'Feline leukemia virus',
#  353765: 'Finkel-Biskis-Jinkins murine sarcoma virus',
#  11840: 'Gibbon ape leukemia virus',
#  11777: 'Feline sarcoma virus (STRAIN HARDY-ZUCKERMAN 4)',
#  11807: 'Harvey murine sarcoma virus',
#  11808: 'Kirsten murine sarcoma virus',
#  394239: 'Koala retrovirus',
#  11809: 'Moloney murine sarcoma virus',
#  11795: 'Friend murine leukemia virus',
#  11801: 'Moloney murine leukemia virus',
#  44561: 'Murine type C retrovirus',
#  11636: 'Reticuloendotheliosis virus',
#  11970: 'Woolly monkey sarcoma virus',
#  11788: 'Abelson murine leukemia virus',
#  11764: 'Baboon endogenous virus strain M7',
#  1038068: 'PreXMRV-1',
#  11830: 'Murine osteosarcoma virus',
#  590745: 'Mus musculus mobilized endogenous polytropic provirus',
#  11834: 'RD114 retrovirus',
#  11819: 'Spleen focus-forming virus',
#  11657: 'Bovine immunodeficiency virus',
#  11660: 'Caprine arthritis encephalitis virus',
#  11665: 'Equine infectious anemia virus',
#  11673: 'Feline immunodeficiency virus',
#  11676: 'Human immunodeficiency virus 1',
#  11709: 'Human immunodeficiency virus 2',
#  36370: 'Jembrana disease virus',
#  32615: 'Puma lentivirus 14',
#  11723: 'Simian immunodeficiency virus',
#  159122: 'Simian immunodeficiency virus SIV-mnd 2',
#  2169971: 'Visna-maedi virus',
#  11663: 'Ovine lentivirus',
#  40270: 'Snakehead retrovirus',
#  207343: 'Bovine foamy virus',
#  109270: 'Equine foamy virus',
#  53182: 'Feline foamy virus',
#  2169894: 'Puma feline foamy virus',
#  2170139: 'Brown greater galago prosimian foamy virus',
#  221703: 'Simian foamy virus Pongo pygmaeus pygmaeus',
#  2170194: 'Central cimpanzee simian foamy virus',
#  2170195: 'Eastern chimpanzee simian foamy virus',
#  2170197: 'Guenon simian foamy virus',
#  2170198: 'Japanese macaque simian foamy virus',
#  2170199: 'Rhesus macaque simian foamy virus',
#  2170200: 'Spider monkey simian foamy virus',
#  2170201: 'Squirrel monkey simian foamy virus',
#  2170204: 'Western lowland gorilla simian foamy virus',
#  2170205: 'White-tufted-ear marmoset simian foamy virus',
#  2170206: 'Yellow-breasted capuchin simian foamy virus',
#  338079: 'African green monkey simian foamy virus',
#  11642: 'Simian foamy virus',
#  348296: 'Atlantic salmon swim bladder sarcoma virus',
#  93465: 'Avian endogenous retrovirus EAV-HP',
#  1435008: 'Citrus endogenous pararetrovirus',
#  166122: 'Human endogenous retrovirus K113',
#  2320522: 'Saesbyeol virus',
#  204873: 'Xenopus laevis endogenous retrovirus Xen1',
#  664255: 'Anthurium mosaic-associated virus',
#  607716: 'Alphachrysovirus aspergilli',
#  1692191: 'Brassica campestris chrysovirus 1',
#  284687: 'Alphachrysovirus cerasi',
#  1766766: 'Colletotrichum gloeosporioides chrysovirus 1',
#  1930960: 'Isaria javanica chrysovirus 1',
#  1708483: 'Macrophomina phaseolina chrysovirus 1',
#  1162393: 'Raphanus sativas chrysovirus 1',
#  1923465: 'Shuangao chryso-like virus 1',
#  759389: 'Verticillium dahliae chrysovirus 1',
#  2682569: 'Chrysothrix chrysovirus 1',
#  399394: 'Cryphonectria nitschkei chrysovirus 1',
#  434898: 'Fusarium oxysporum chrysovirus 1',
#  158372: 'Penicillium chrysogenum virus',
#  1587509: 'Persea americana chrysovirus',
#  2382121: 'Zea mays chrysovirus 1',
#  2066695: 'Alternaria alternata chrysovirus 1',
#  2164061: 'Betachrysovirus aspergilli',
#  1405299: 'Botryosphaeria dothidea chrysovirus 1',
#  1679238: 'Fusarium oxysporum f. sp. dianthi mycovirus 1',
#  254946: 'Fusarium graminearum dsRNA mycovirus 2',
#  2304034: 'Colletotrichum fructicola chrysovirus 1',
#  2587540: 'Coniothyrium diplodiella chrysovirus 1',
#  2587541: 'Neofusicoccum parvum chrysovirus 1',
#  1755792: 'Penicillium janczewskii chrysovirus 1',
#  1755793: 'Penicillium janczewskii chrysovirus 2',
#  164750: 'Helminthosporium victoriae 145S virus',
#  764348: 'Magnaporthe oryzae chrysovirus 1',
#  658904: 'Rosellinia necatrix megabirnavirus 1/W779',
#  1676267: 'Rosellinia necatrix megabirnavirus 2-W8',
#  1661257: 'Sclerotinia sclerotiorum megabirnavirus 1',
#  1000373: 'Rosellinia necatrix quadrivirus 1',
#  29255: 'Giardia lamblia virus',
#  2082658: 'Gigaspora margarita giardia-like virus 1',
#  58103: 'Leishmania RNA virus 1 - 1',
#  12530: 'Leishmania RNA virus 1 - 4',
#  39116: 'Leishmania RNA virus 2 - 1',
#  1497019: 'Leishmania aethiopica RNA virus',
#  11008: 'Saccharomyces cerevisiae virus L-A',
#  42478: 'Saccharomyces cerevisiae virus L-BC (La)',
#  1300323: 'Scheffersomyces segobiensis virus L',
#  927810: 'Tuber aestivum virus 1',
#  28882: 'Ustilago maydis virus H1',
#  1167690: 'Xanthophyllomyces dendrorhous virus L1A',
#  1167691: 'Xanthophyllomyces dendrorhous virus L1B',
#  463392: 'Black raspberry virus F',
#  425009: 'Botryotinia fuckeliana totivirus 1',
#  279539: 'Gremmeniella abietina RNA virus L2',
#  674953: 'Trichomonas vaginalis virus 1',
#  674954: 'Trichomonas vaginalis virus 2',
#  170965: 'Trichomonas vaginalis virus 3',
#  1008292: 'Trichomonas vaginalis virus 4',
#  1087070: 'Aspergillus foetidus slow virus 1',
#  1685109: 'Beauveria bassiana victorivirus 1',
#  267285: 'Chalara elegans RNA Virus 1',
#  210827: 'Coniothyrium minitans RNA virus',
#  382962: 'Epichloe festucae virus 1',
#  152217: 'Gremmeniella abietina RNA virus L1',
#  196690: 'Helicobasidium mompa totivirus 1-17',
#  45237: 'Helminthosporium victoriae virus 190S',
#  271257: 'Magnaporthe oryzae virus 1',
#  441999: 'Magnaporthe oryzae virus 2',
#  1148491: 'Rosellinia necatrix victorivirus 1',
#  73497: 'Sphaeropsis sapinea RNA virus 1',
#  73498: 'Sphaeropsis sapinea RNA virus 2',
#  939923: 'Tolypocladium cylindrosporum virus 1',
#  1728964: 'Alternaria arborescens victorivirus 1',
#  1485922: 'Beauveria bassiana victorivirus NZL/1980',
#  1547580: 'Botryosphaeria dothidea victorivirus 1',
#  1566868: 'Eimeria tenella RNA virus 1',
#  2268743: 'Fusarium asiaticum victorivirus 1',
#  1849535: 'Fusarium poae victorivirus 1',
#  1661396: 'Magnaporthe oryzae virus 3',
#  1765736: 'Nigrospora oryzae victorivirus 1',
#  1580605: 'Phomopsis vexans RNA virus',
#  1859161: 'Sclerotinia nivalis victorivirus 1',
#  1312445: 'Ustilaginoidea virens RNA virus 1',
#  1460374: 'Ustilaginoidea virens RNA virus 3',
#  1756615: 'Ustilaginoidea virens RNA virus 5',
#  1561171: 'Ustilaginoidea virens RNA virus L',
#  1561172: 'Ustilaginoidea virens RNA virus M',
#  556524: 'Armigeres subalbatus virus SaX06-AK20',
#  2026601: 'Australian Anopheles totivirus',
#  1765754: 'Camponotus nipponicus virus',
#  1608533: 'Camponotus yamaokai virus',
#  1870981: 'Culex tritaeniorhynchus totivirus',
#  1678170: 'Diatom colony associated dsRNA virus 10',
#  1678171: 'Diatom colony associated dsRNA virus 11',
#  1678172: 'Diatom colony associated dsRNA virus 12',
#  1678173: 'Diatom colony associated dsRNA virus 13',
#  1678161: 'Diatom colony associated dsRNA virus 3',
#  1678162: 'Diatom colony associated dsRNA virus 4 genome type A',
#  1678163: 'Diatom colony associated dsRNA virus 4 genome type B',
#  1678164: 'Diatom colony associated dsRNA virus 5',
#  1678165: 'Diatom colony associated dsRNA virus 6',
#  1678166: 'Diatom colony associated dsRNA virus 7',
#  1678167: 'Diatom colony associated dsRNA virus 8',
#  1678168: 'Diatom colony associated dsRNA virus 9 genome type A',
#  663282: 'Drosophila melanogaster totivirus SW-2009a',
#  155414: 'Eimeria brunetti RNA virus 1',
#  1898175: 'Eimeria stiedai RNA virus 1',
#  1856030: 'Golden shiner totivirus',
#  1353795: 'Leptopilina boulardi Toti-like virus',
#  1729670: 'Maize-associated totivirus 1',
#  1874267: 'Maize-associated totivirus 2',
#  2057198: 'Maize-associated totivirus 3',
#  1777016: 'Panax notoginseng virus A',
#  2248770: 'Panax notoginseng virus B',
#  1497848: 'Papaya meleira virus',
#  282786: 'Penaeid shrimp infectious myonecrosis virus',
#  1755467: 'Penicillium aurantiogriseum totivirus 1',
#  1833938: 'Penicillium digitatum virus 1',
#  349681: 'Phlebiopsis gigantea mycovirus dsRNA 1',
#  912320: 'Piscine myocarditis virus AL V-708',
#  1798085: 'Piscine myocarditis-like virus',
#  2137353: 'Pythium polare RNA virus 1',
#  2137354: 'Pythium polare RNA virus 2',
#  1714362: 'Red clover powdery mildew-associated totivirus 1',
#  1714363: 'Red clover powdery mildew-associated totivirus 2',
#  1714364: 'Red clover powdery mildew-associated totivirus 3',
#  1714366: 'Red clover powdery mildew-associated totivirus 5',
#  1714367: 'Red clover powdery mildew-associated totivirus 6',
#  1714368: 'Red clover powdery mildew-associated totivirus 7',
#  1714370: 'Red clover powdery mildew-associated totivirus 9',
#  1921825: 'Saccharomyces kudriavzevii virus L-A1',
#  2082585: 'Sogatella furcifera totivirus 1',
#  2082586: 'Sogatella furcifera totivirus 2',
#  1770613: 'Thelephora terrestris virus 1',
#  1163537: 'Tianjin totivirus',
#  29256: 'Trichomonas vaginalis virus',
#  273810: 'Eriocheir sinensis reovirus',
#  338781: 'Micromonas pusilla reovirus',
#  40050: 'African horse sickness virus',
#  40051: 'Bluetongue virus',
#  40052: 'Changuinola virus',
#  40065: 'Chenuda virus',
#  1679172: 'Chobar Gorge virus',
#  40053: 'Corriparta virus',
#  449133: 'Epizootic hemorrhagic disease virus (serotype 1 / strain New Jersey)',
#  201490: 'Equine encephalosis virus',
#  40056: 'Eubenangee virus',
#  204269: 'Great Island virus',
#  40057: 'Lebombo virus',
#  40058: 'Orungo virus',
#  40059: 'Palyam virus',
#  356862: 'Peruvian horse sickness virus',
#  104581: 'St Croix River virus',
#  40060: 'Umatilla virus',
#  40067: 'Wad Medani virus',
#  40061: 'Wallal virus',
#  40062: 'Warrego virus',
#  47465: 'Wongorr virus',
#  306276: 'Yunnan orbivirus',
#  2306813: 'Guangxi orbivirus',
#  1408137: 'Mobuck virus',
#  1955493: 'Orbivirus SX-2017a',
#  559180: 'Stretch Lagoon orbivirus',
#  1692107: 'Fengkai orbivirus',
#  10991: 'Rice dwarf virus',
#  10986: 'Rice gall dwarf virus',
#  10987: 'Wound tumor virus',
#  411854: 'Homalodisca vitripennis reovirus',
#  28875: 'Rotavirus A',
#  10942: 'Human rotavirus B',
#  36427: 'Rotavirus C',
#  884200: 'Rotavirus D chicken/05V0049/DEU/2005',
#  994994: 'Rotavirus F chicken/03V0568/DEU/2003',
#  994995: 'Rotavirus G chicken/03V0567/DEU/2003',
#  335103: 'Adult diarrheal rotavirus strain J19',
#  1637496: 'Rotavirus I',
#  1929964: 'Rotavirus J',
#  1340801: 'Bat rotavirus',
#  649604: 'Banna virus strain JKT-6423',
#  104580: 'Kadipiro virus',
#  246280: 'Liao ning virus',
#  173082: 'Chum salmon reovirus CS',
#  1382300: 'Green River chinook virus',
#  185782: 'Aquareovirus C',
#  994485: 'Scophthalmus maximus reovirus',
#  465447: 'American grass carp reovirus',
#  1862978: 'Etheostoma fonticola aquareovirus',
#  1963254: 'Fall chinook aquareovirus',
#  46839: 'Colorado tick fever virus',
#  62352: 'Eyach virus',
#  2290890: 'Kundal virus',
#  2014339: 'Tarumizu tick virus',
#  205895: 'Cypovirus 1',
#  205908: 'Cypovirus 14',
#  134606: 'Trichoplusia ni cypovirus 15',
#  480410: 'Choristoneura occidentalis cypovirus 16',
#  1382295: 'Inachis io cypovirus 2',
#  205899: 'Cypovirus 5',
#  1986950: 'Daphnis nerii cypovirus',
#  1577776: 'Dendrolimus punctatus cypovirus 22',
#  341721: 'Aedes pseudoscutellaris reovirus',
#  1567404: 'Fako virus',
#  77698: 'Fiji disease virus',
#  10989: 'Maize rough dwarf virus',
#  185954: 'Mal de Rio Cuarto virus',
#  33724: 'Nilaparvata lugens reovirus',
#  73147: 'Oat sterile dwarf virus',
#  10990: 'Rice black streaked dwarf virus',
#  519497: 'Southern rice black-streaked dwarf virus',
#  37368: 'Diadromus pulchellus idnoreovirus 1',
#  311228: 'Mycoreovirus 1',
#  404238: 'Cryphonectria parasitica mycoreovirus 2 (C18)',
#  311229: 'Mycoreovirus 3',
#  1840528: 'Sclerotinia sclerotiorum mycoreovirus 4',
#  38170: 'Avian orthoreovirus',
#  75888: 'Baboon orthoreovirus',
#  2170064: 'Mahlapitsi orthoreovirus',
#  538123: 'Mammalian orthoreovirus 3',
#  253454: 'Pulau reovirus',
#  1157337: 'Piscine orthoreovirus',
#  226613: 'Reptilian orthoreovirus',
#  667093: 'Broome virus',
#  1462685: 'Bush viper reovirus',
#  1388882: 'Cangyuan orthoreovirus',
#  419697: 'Melaka orthoreovirus',
#  42475: 'Rice ragged stunt virus',
#  2250219: 'Chiqui virus',
#  1811230: 'Callinectes sapidus reovirus 1',
#  1427476: 'Cimodo virus',
#  1640277: 'Grapevine Cabernet Sauvignon reovirus',
#  1670669: 'Lutzomyia reovirus 1',
#  2108203: 'Nephila clavipes virus 6',
#  352248: 'Operophtera brumata reovirus',
#  907191: 'Raspberry latent virus',
#  1004049: 'Spissistilus festinus reovirus',
#  161736: 'Pseudomonas phage phi12',
#  134554: 'Pseudomonas phage phi13',
#  593131: 'Pseudomonas phage phi2954',
#  2928686: 'Pseudomonas phage phi6',
#  120086: 'Pseudomonas phage phi8',
#  1603039: 'Pseudomonas phage phiNN',
#  1852644: 'Pseudomonas phage phiYY',
#  2058778: 'Allium cepa amalgavirus 1',
#  2058779: 'Allium cepa amalgavirus 2',
#  430710: 'Blueberry latent virus',
#  878260: 'Rhododendron virus A',
#  591166: 'Southern tomato virus',
#  1985164: 'Spinach amalgavirus 1',
#  114871: 'Zygosaccharomyces bailii virus Z',
#  2065797: 'Anthoxanthum odoratum amalgavirus 1',
#  1872708: 'Antonospora locustae virus 1',
#  2069319: 'Camellia oleifera amalgavirus 1',
#  2069320: 'Capsicum annuum amalgavirus 1',
#  2069321: 'Cleome droserifolia amalgavirus 1',
#  2069322: 'Erigeron breviscapus amalgavirus 1',
#  2069323: 'Erigeron breviscapus amalgavirus 2',
#  2069324: 'Festuca pratensis amalgavirus 1',
#  2069325: 'Festuca pratensis amalgavirus 2',
#  2069326: 'Medicago sativa amalgavirus 1',
#  2069327: 'Phalaenopsis equestris amalgavirus 1',
#  2419805: 'Salvia hispanica RNA virus 1',
#  1985202: 'Zostera marina amalgavirus 1',
#  1985203: 'Zostera marina amalgavirus 2',
#  421976: 'Curvularia thermal tolerance virus',
#  687918: 'Fusarium graminearum dsRNA mycovirus 4',
#  1895000: 'Sclerotium hydrophilum virus 1',
#  2315392: 'Trichoderma harzianum bipartite mycovirus 1',
#  509923: 'Beet cryptic virus 1',
#  589918: 'Carrot cryptic virus',
#  284689: 'Amasya cherry disease-associated mycovirus',
#  529380: 'Chondrostereum purpureum cryptic virus 1',
#  568090: 'Flammulina velutipes browning virus',
#  91913: 'Helicobasidium mompa dsRNA mycovirus',
#  942041: 'Heterobasidion partitivirus 1',
#  1469905: 'Heterobasidion partitivirus 12',
#  1469906: 'Heterobasidion partitivirus 13',
#  1469908: 'Heterobasidion partitivirus 15',
#  631431: 'Heterobasidion partitivirus 3',
#  859651: 'Rosellinia necatrix partitivirus 2',
#  54289: 'Vicia cryptic virus',
#  292052: 'White clover cryptic virus 1',
#  2043550: 'Medicago sativa alphapartitivirus 1',
#  1825688: 'Rhizoctonia solani dsRNA virus 3',
#  37961: 'Atkinsonella hypoxylon virus',
#  1115692: 'Cannabis cryptic virus',
#  674982: 'Ceratocystis resinifera virus 1',
#  235434: 'Ceratocystis polonica partitivirus',
#  1323528: 'Crimson clover cryptic virus 2',
#  1323529: 'Dill cryptic virus 2',
#  75747: 'Fusarium poae virus 1',
#  1849534: 'Fusarium poae virus 1-240374',
#  872291: 'Heterobasidion partitivirus 2',
#  1387301: 'Heterobasidion partitivirus 7',
#  1249677: 'Heterobasidion partitivirus 8',
#  186815: 'Heterobasidion annosum P-type partitivirus',
#  1323523: 'Hop trefoil cryptic virus 2',
#  674983: 'Pleurotus ostreatus virus 1',
#  479713: 'Primula malacoides virus China/Mar2007',
#  1323524: 'Red clover cryptic virus 2',
#  46618: 'Rhizoctonia solani virus 717',
#  235994: 'Rosellinia necatrix partitivirus 1-W8',
#  1323525: 'White clover cryptic virus 2',
#  1573459: 'Rosellinia necatrix partitivirus 6',
#  675060: 'Cryptosporidium parvum virus 1',
#  912029: 'Beet cryptic virus 2',
#  29257: 'Beet cryptic virus 3',
#  882768: 'Fig cryptic virus',
#  369643: 'Pepper cryptic virus 1',
#  1050903: 'Pepper cryptic virus 2',
#  358008: 'Aspergillus ochraceous virus',
#  148880: 'Discula destructiva virus 1',
#  160484: 'Discula destructiva virus 2',
#  1511847: 'Fusarium solani virus 1',
#  191436: 'Gremmeniella abietina RNA virus MS1',
#  347482: 'Ophiostoma partitivirus 1',
#  296210: 'Penicillium stoloniferum virus F',
#  216371: 'Penicillium stoloniferum virus S',
#  2083275: 'Pythium nunn virus 1',
#  1849335: 'Arabidopsis halleri partitivirus 1',
#  2250452: 'Aspergillus fumigatus partitivirus 2',
#  1980631: 'Bipolaris maydis partitivirus 1',
#  2483307: 'Bipolaris maydis partitivirus 2',
#  1516075: 'Botryosphaeria dothidea virus 1',
#  425010: 'Botryotinia fuckeliana partitivirus 1',
#  1980625: 'Carnation cryptic virus 3',
#  1408895: 'Dill cryptic virus 1',
#  335204: 'Fragaria chiloensis cryptic virus',
#  1849533: 'Fusarium poae partitivirus 2',
#  2305257: 'Melon partitivirus',
#  1756157: 'Penicillium aurantiogriseum partitivirus 1',
#  1183241: 'Persimmon cryptic virus',
#  1685502: 'Pseudogymnoascus destructans partitivirus-pa',
#  348449: 'Raphanus sativus cryptic virus 1',
#  351495: 'Raphanus sativus cryptic virus 2',
#  580254: 'Raphanus sativus cryptic virus 3',
#  1408894: 'Red clover cryptic virus 1',
#  1411681: 'Rhizoctonia solani dsRNA virus 2',
#  2045504: 'Rhizoctonia solani dsRNA virus 4',
#  492502: 'Rose cryptic virus 1',
#  2025333: 'Rosellinia necatrix partitivirus 8',
#  659497: 'Sclerotinia sclerotiorum partitivirus S',
#  1768874: 'Sinapis alba cryptic virus 1',
#  1891704: 'Sophora japonica powdery mildew-associated partitivirus',
#  1937817: 'Spinach cryptic virus 1',
#  1415665: 'Ustilaginoidea virens partitivirus 2',
#  1310424: 'Verticillium dahliae partitivirus 1',
#  145856: 'Human picobirnavirus',
#  104395: 'Rabbit picobirnavirus',
#  1930304: 'Chicken picobirnavirus',
#  1187973: 'Otarine picobirnavirus',
#  1961162: 'Picobirnavirus dog/KNA/2015',
#  1961155: 'Picobirnavirus green monkey/KNA/2015',
#  1907787: 'Picobirnavirus sp.',
#  442302: 'Porcine picobirnavirus',
#  11002: 'Infectious pancreatic necrosis virus',
#  359996: 'Tellina virus 2',
#  59816: 'Yellowtail ascites virus',
#  1721090: 'Tasmanian aquabirnavirus',
#  1661392: 'Victorian trout aquabirnavirus',
#  10995: 'Infectious bursal disease virus',
#  311176: 'Blotched snakehead virus',
#  2583366: 'Lates calcarifer birnavirus',
#  48981: 'Drosophila X virus',
#  321302: 'Tellina virus 1',
#  1127767: 'Espirito Santo virus',
#  1918014: 'Botrytis porri botybirnavirus 1',
#  2138326: 'Bipolaris maydis botybirnavirus 1',
#  1654339: 'Sclerotinia sclerotiorum botybirnavirus 1',
#  2250469: 'Aspergillus fumigatus polymycovirus 1',
#  1740646: 'Beauveria bassiana polymycovirus 1',
#  1529605: 'Cladosporium cladosporioides virus 1',
#  2546034: 'Fusarium redolens polymycovirus 1',
#  2509266: 'Magnaporthe oryzae polymycovirus 1',
#  2164101: 'Penicillium digitatum polymycoviruses 1',
#  2485923: 'Penicillium brevicompactum tetramycovirus 1',
#  483537: 'Alternaria alternata virus 1',
#  1532031: 'Alternaria longipes dsRNA virus 1',
#  1087068: 'Aspergillus foetidus dsRNA mycovirus',
#  1054649: 'Beauveria bassiana RNA virus 1',
#  1568973: 'Botrytis cinerea RNA virus 1',
#  862944: 'Circulifer tenellus virus 1',
#  1565088: 'Colletotrichum higginsianum non-segmented dsRNA virus 1',
#  1329781: 'Cryphonectria parasitica bipartite mycovirus 1',
#  1678177: 'Diatom colony associated dsRNA virus 17 genome type A',
#  1678178: 'Diatom colony associated dsRNA virus 17 genome type B',
#  1678160: 'Diatom colony associated dsRNA virus 2',
#  459770: 'Diplodia scrobiculata RNA virus 1',
#  194397: 'Fusarium graminearum dsRNA mycovirus-1',
#  687917: 'Fusarium graminearum dsRNA mycovirus-3',
#  1848042: 'Fusarium poae dsRNA virus 2',
#  1848169: 'Fusarium poae dsRNA virus 3',
#  1849542: 'Fusarium poae mycovirus 1',
#  1849543: 'Fusarium poae mycovirus 2',
#  1150353: 'Gentian Kobu-sho-associated virus',
#  1211481: 'Persimmon latent virus',
#  12450: 'Saccharomyces cerevisiae killer virus M1',
#  1181310: 'Sclerotinia sclerotiorum dsRNA mycovirus-L',
#  862943: 'Spissistilus festinus virus 1',
#  2305250: 'Trichoderma asperellum dsRNA virus 1',
#  1934322: 'Trichoderma atroviride mycovirus',
#  2305465: 'Ustilaginoidea virens nonsegmented virus 2',
#  1670975: 'Ustilaginoidea virens unassigned RNA virus HNND-1',
#  1148496: 'Yado-kari virus 1',
#  2094187: 'Yado-nushi virus 1-A',
#  40281: 'Cryphonectria hypovirus 1',
#  40282: 'Cryphonectria hypovirus 2',
#  106962: 'Cryphonectria hypovirus 3',
#  245101: 'Cryphonectria hypovirus 4',
#  1284208: 'Fusarium graminearum hypovirus 1',
#  1640379: 'Fusarium graminearum hypovirus 2',
#  1523858: 'Phomopsis longicolla hypovirus',
#  2032989: 'Rosellinia necatrix hypovirus 1',
#  1074325: 'Sclerotinia sclerotiorum hypovirus 1',
#  1423347: 'Sclerotinia sclerotiorum hypovirus 2',
#  1129873: 'Valsa ceratosperma hypovirus 1',
#  1922393: 'Beihai hypo-like virus 1',
#  1922678: 'Beihai sipunculid worm virus 6',
#  2219105: 'Botrytis cinerea hypovirus 1',
#  1926644: 'Fusarium langsethiae hypovirus 1',
#  1923718: 'Wuhan insect virus 14',
#  2012619: "Olivier's shrew virus 1",
#  11047: 'Equine arteritis virus',
#  1965064: 'African pouched rat arterivirus',
#  38143: 'Simian hemorrhagic fever virus',
#  1965068: 'Simian hemorrhagic encephalitis virus',
#  1737586: 'Free State vervet virus',
#  2682610: 'Zambian malbrouck virus 1',
#  1936072: 'Kibale red colobus virus 2',
#  1965063: "DeBrazza's monkey arterivirus",
#  1965065: 'Kibale red-tailed guenon virus 1',
#  1658615: 'Pebjah virus',
#  1823757: 'Kafue kinda chacma baboon virus',
#  1546177: 'Mikumi yellow baboon virus 1',
#  1885929: 'Kibale red colobus virus 1',
#  1965067: 'Porcine reproductive and respiratory syndrome virus 2',
#  1734441: 'Rat arterivirus 1',
#  11049: 'Lelystad virus',
#  11048: 'Lactate dehydrogenase-elevating virus',
#  1118369: 'Wobbly possum disease virus',
#  28344: 'Porcine reproductive and respiratory syndrome virus',
#  1806636: 'Rodent arterivirus',
#  1546178: 'Southwest baboon virus 1',
#  2116345: 'Chinese broad-headed pond turtle arterivirus',
#  2116442: 'Guangdong greater green snake arterivirus',
#  2116440: 'Hainan oligodon formosanus arterivirus',
#  1508220: 'Bat coronavirus',
#  2050018: 'Rodent coronavirus',
#  1384461: 'Bat coronavirus CDPHE15/USA/2006',
#  1241933: 'Rousettus bat coronavirus HKU10',
#  1503292: 'BtRf-AlphaCoV/HuB2013',
#  11137: 'Human coronavirus 229E',
#  1699095: 'Camel alphacoronavirus',
#  1508224: 'Lucheng Rn rat coronavirus',
#  1964806: 'Coronavirus AcCoV-JC34',
#  1264898: 'Ferret coronavirus',
#  766791: 'Mink coronavirus strain WD1127',
#  393767: 'Bat coronavirus 1A',
#  694001: 'Miniopterus bat coronavirus HKU8',
#  1503289: 'BtMr-AlphaCoV/SAX2011',
#  1503291: 'BtNv-AlphaCoV/SC2013',
#  2492658: 'Alphacoronavirus Bat-CoV/P.kuhlii/Italy/3398-19/2015',
#  28295: 'Porcine epidemic diarrhea virus',
#  693999: 'Scotophilus bat coronavirus 512',
#  693998: 'Rhinolophus bat coronavirus HKU2',
#  1503293: 'BtRf-AlphaCoV/YN2012',
#  277944: 'Human coronavirus NL63',
#  1920748: 'NL63-related bat coronavirus',
#  11135: 'Feline infectious peritonitis virus',
#  1766554: 'Swine enteric coronavirus',
#  11149: 'Transmissible gastroenteritis virus',
#  1508228: 'Wencheng Sm shrew coronavirus',
#  11128: 'Bovine coronavirus',
#  31631: 'Human coronavirus OC43',
#  1590370: 'Betacoronavirus HKU24',
#  290028: 'Human coronavirus HKU1',
#  11138: 'Murine hepatitis virus',
#  11144: 'Murine hepatitis virus strain JHM',
#  502102: 'Rat coronavirus Parker',
#  1160968: 'Rabbit coronavirus HKU14',
#  1541205: 'Bat Hp-betacoronavirus/Zhejiang2013',
#  1385427: 'Betacoronavirus Erinaceus/VMC/DEU/2012',
#  1335626: 'Middle East respiratory syndrome-related coronavirus',
#  1263720: 'Betacoronavirus England 1',
#  694008: 'Pipistrellus bat coronavirus HKU5',
#  694007: 'Tylonycteris bat coronavirus HKU4',
#  1892416: 'Rousettus bat coronavirus',
#  694006: 'Rousettus bat coronavirus HKU9',
#  2697049: 'Severe acute respiratory syndrome coronavirus 2',
#  227984: 'SARS coronavirus Tor2',
#  864596: 'Bat coronavirus BM48-31/BGR/2008',
#  1159908: 'Wigeon coronavirus HKU20',
#  572288: 'Bulbul coronavirus HKU11-934',
#  1159902: 'Common moorhen coronavirus HKU21',
#  1159905: 'Porcine coronavirus HKU15',
#  572289: 'Munia coronavirus HKU13-3514',
#  1159907: 'White-eye coronavirus HKU16',
#  1159903: 'Magpie-robin coronavirus HKU18',
#  1159906: 'Sparrow coronavirus HKU17',
#  572290: 'Thrush coronavirus HKU12-600',
#  1159904: 'Night heron coronavirus HKU19',
#  694015: 'Beluga whale coronavirus SW1',
#  300188: 'Duck coronavirus',
#  11120: 'Infectious bronchitis virus',
#  11152: 'Turkey coronavirus',
#  2569586: 'Canada goose coronavirus',
#  2050019: 'Shrew coronavirus',
#  1922350: 'Beihai Nido-like virus 1',
#  2509395: 'Botrylloides leachii nidovirus',
#  1945562: 'Alphamesonivirus 4',
#  1482319: 'Casuarina virus',
#  1795438: 'Kadiweu virus',
#  1945560: 'Alphamesonivirus 2',
#  1332248: 'Karang Sari virus',
#  1945561: 'Alphamesonivirus 3',
#  1238455: 'Dak Nong virus',
#  2060479: 'Dianke virus',
#  1041929: 'Cavally virus',
#  325676: 'Nam Dinh virus',
#  1795442: 'Ofaie virus',
#  2053026: 'Yichang virus',
#  2100419: 'Planarian secretory cell nidovirus',
#  2116441: 'Nanhai ghost shark arterivirus',
#  2116443: 'Wuhan japanese halfbeak arterivirus',
#  1922351: 'Beihai Nido-like virus 2',
#  1923510: 'Wenling nido-like virus 1',
#  1922391: 'Beihai hermit crab virus 4',
#  96029: 'Yellow head virus',
#  405554: 'White bream virus',
#  889873: 'Fathead minnow nidovirus',
#  1611837: 'Chinook salmon bafinivirus',
#  1631554: 'Bovine nidovirus TCH5',
#  1923777: 'Xinzhou toro-like virus',
#  1986118: 'Ball python nidovirus 1',
#  2016400: 'Morelia viridis nidovirus',
#  2301728: 'Bellinger River virus',
#  1912590: 'Shingleback nidovirus 1',
#  1923774: 'Xinzhou nematode virus 6',
#  46473: 'Breda virus',
#  329862: 'Equine torovirus',
#  11156: 'Berne virus',
#  237020: 'Porcine torovirus',
#  1837217: 'Goat torovirus',
#  2116384: 'Guangdong red-banded snake torovirus',
#  2116385: 'Hainan hebius popei torovirus',
#  2283236: 'Aplysia californica nido-like virus',
#  1172196: 'Chicken calicivirus',
#  33756: 'European brown hare syndrome virus',
#  11976: 'Rabbit hemorrhagic disease virus',
#  576948: 'Rabbit calicivirus Australia 1 MIC-07',
#  1949201: 'Fathead minnow calicivirus',
#  1172195: 'Turkey calicivirus',
#  2847999: 'Nebraska virus',
#  331642: 'Newbury agent 1',
#  1812179: 'Bovine calicivirus strain Kirklareli',
#  11983: 'Norwalk virus',
#  122928: 'Norovirus GI',
#  1529909: 'Norovirus GI/Hu/JP/2007/GI.P3_GI.3/Shimizu/KK2866',
#  122929: 'Norovirus GII',
#  1529918: 'Norovirus GII/Hu/JP/2007/GII.P15_GII.15/Sapporo/HK299',
#  1529924: 'Norovirus GII/Hu/JP/2011/GII/Yuzawa/Gira2HS',
#  552592: 'Norovirus GII.17',
#  490039: 'Norovirus GII.2',
#  340017: 'Norovirus GIII',
#  262897: 'Norovirus GIV',
#  673457: 'Norovirus dog/GVI.1/HKU_Ca026F/2007/HKG',
#  1246677: 'Norovirus GV',
#  95340: 'Norwalk-like virus',
#  2161807: 'Marmot norovirus',
#  1903318: 'Primate norovirus',
#  512169: 'Tulane virus',
#  1489836: 'Atlantic salmon calicivirus',
#  2849715: 'Cowden I virus',
#  290314: 'Sapovirus C12',
#  234601: 'Sapovirus Mc10',
#  291175: 'Sapovirus Hu/Dresden/pJG-Sap01/DE',
#  1280920: 'Sapovirus Hu/Nagoya/NGY-1/2012/JPN',
#  1959930: 'Bat sapovirus',
#  1185359: 'Bat sapovirus TLC58/HK',
#  11978: 'Feline calicivirus',
#  35612: 'Vesicular exanthema of swine virus',
#  146073: 'Walrus calicivirus',
#  1176484: 'Canine vesivirus',
#  1960046: 'Hom-1 vesivirus',
#  154122: 'Mink calicivirus',
#  303317: 'Rabbit vesivirus',
#  1564182: 'San Miguel sea lion virus 8',
#  436911: 'Steller sea lion vesivirus',
#  1615583: 'Vesivirus ferret badger/JX12/China/2012',
#  243550: 'Calicivirus isolate TCG',
#  1493858: 'Goose calicivirus',
#  520973: 'Calicivirus pig/AB90/CAN',
#  92444: 'Acute bee paralysis virus',
#  294365: 'Israeli acute paralysis virus',
#  68876: 'Kashmir bee virus',
#  932662: 'Mud crab virus',
#  294369: 'Solenopsis invicta virus 1',
#  142102: 'Taura syndrome virus',
#  209529: 'Aphid lethal paralysis virus',
#  12136: 'Cricket paralysis virus',
#  64279: 'Drosophila C virus',
#  66834: 'Rhopalosiphum padi virus',
#  1769780: 'Anopheles C virus',
#  2005444: 'Aphis glycines virus 3',
#  92395: 'Black queen cell virus',
#  81583: 'Himetobi P virus',
#  2170238: 'Homalodisca coagulata virus 1',
#  64698: 'Plautia stali intestine virus',
#  103442: 'Triatoma virus',
#  1983569: 'Apis dicistrovirus',
#  1041883: 'Big Sioux River virus',
#  1926967: 'Bivalve RNA virus G1',
#  1926968: 'Bivalve RNA virus G5',
#  1916650: 'Centovirus AC',
#  1911442: 'Mosquito dicistrovirus',
#  1432856: 'Formica exsecta virus 1',
#  1776109: 'Goose dicistrovirus',
#  1027947: 'Macrobrachium rosenbergii Taihu virus',
#  1460071: 'Antheraea pernyi iflavirus',
#  436447: 'Brevicoryne brassicae virus - UK',
#  198112: 'Deformed wing virus',
#  1541119: 'Dinocampus coccinellae paralysis virus',
#  240555: 'Ectropis obliqua picorna-like virus',
#  12742: 'Infectious flacherie virus',
#  1072333: 'Lygus lineolaris virus 1',
#  1521188: 'Lymantria dispar iflavirus 1',
#  1267585: 'Nilaparvata lugens honeydew virus 1',
#  170621: 'Perina nuda virus',
#  89463: 'Sacbrood virus',
#  458132: 'Slow bee paralysis virus',
#  1111710: 'Spodoptera exigua iflavirus 1',
#  1228012: 'Spodoptera exigua iflavirus 2',
#  232800: 'Varroa destructor virus 1',
#  2018471: 'Armigeres iflavirus',
#  1958778: 'Bat iflavirus',
#  1690666: 'Bombyx mori iflavirus',
#  1972700: 'Diamondback moth iflavirus',
#  1432857: 'Formica exsecta virus 2',
#  1487185: 'Heliconius erato iflavirus',
#  1936269: 'Helicoverpa armigera iflavirus',
#  1906245: 'Moku virus',
#  2358449: 'Psammotettix alienus iflavirus 1',
#  2054920: 'Chequa iflavirus',
#  2304477: 'Culex Iflavi-like virus 1',
#  2304480: 'Culex Iflavi-like virus 4',
#  1920698: 'Euscelidius variegatus virus 1',
#  1629132: 'Graminella nigrifrons virus 1',
#  1410467: 'Halyomorpha halys virus',
#  1911104: 'King virus',
#  1654357: 'La Jolla virus',
#  1464786: 'Laodelphax striatella honeydew virus 1',
#  1566869: 'Laodelphax striatellus picorna-like virus 2',
#  2099521: 'Nesidiocoris tenuis iflavirus 1',
#  1345661: 'Nilaparvata lugens honeydew virus-2',
#  1345662: 'Nilaparvata lugens honeydew virus-3',
#  1675864: 'Opsiphanes invirae iflavirus 1',
#  1965238: 'Pityohyphantes rubrofasciatus iflavirus',
#  1591444: 'Thaumetopoea pityocampa iflavirus 1',
#  2056384: 'Varroa destructor virus 2',
#  2315809: 'Yongsan iflavirus 1',
#  2169725: 'Chaetoceros socialis forma radians RNA virus 1',
#  497136: 'Chaetoceros tenuissimus RNA virus 01',
#  359987: 'Rhizosolenia setigera RNA virus 01',
#  1522179: 'Asterionellopsis glacialis RNA virus',
#  674971: 'Aurantiochytrium single-stranded RNA virus 01',
#  439016: 'Marine RNA virus JP-B',
#  1198329: 'Marine RNA virus SF-1',
#  1416631: 'Marine RNA virus SF-2',
#  1419327: 'Marine RNA virus SF-3',
#  324900: 'Heterosigma akashiwo RNA virus',
#  2315691: 'Marine RNA virus BC-1',
#  2315763: 'Marine RNA virus BC-4',
#  1804153: 'Marine RNA virus PAL128',
#  1804156: 'Marine RNA virus PAL473',
#  1958784: 'Bat dicibavirus',
#  2315692: 'Marine RNA virus BC-2',
#  2315693: 'Marine RNA virus BC-3',
#  1045800: 'Chaetoceros species RNA virus 02',
#  439015: 'Marine RNA virus JP-A',
#  1804154: 'Marine RNA virus PAL156',
#  1482734: 'Duck aalivirus 1',
#  2016447: 'Aimelvirus 1',
#  1661395: 'Ampivirus A1',
#  2870363: 'anativirus A1',
#  1155188: 'Bovine rhinitis A virus',
#  2758977: 'bovine rhinitis B virus 1',
#  47000: 'Equine rhinitis A virus',
#  12118: 'Foot-and-mouth disease virus O',
#  1606765: 'Bovine rhinovirus 1',
#  471728: 'Seal picornavirus type 1',
#  1006061: 'Duck hepatitis A virus 1',
#  1293536: 'Turkey avisivirus',
#  1534545: 'Chicken picornavirus 2',
#  1534546: 'Chicken picornavirus 3',
#  1766559: 'Avisivirus Pf-CHK1/AsV',
#  1564115: 'Bovine picornavirus',
#  12104: 'Encephalomyocarditis virus',
#  204711: 'Theilovirus',
#  511755: 'Human TMEV-like cardiovirus',
#  434309: 'Saffold virus',
#  2034827: 'cardiovirus C1',
#  1330491: 'Cosavirus A',
#  586420: 'Human cosavirus B',
#  2003650: 'Cosavirus D',
#  2003651: 'Cosavirus E',
#  2003652: 'Cosavirus F',
#  1582094: 'Cosavirus JMY-2014',
#  1233383: 'Human cosavirus',
#  2169853: 'Crohivirus A',
#  2169854: 'Crohivirus B',
#  1150861: 'Canine picodicistrovirus',
#  2041149: 'Hedgehog dicipivirus',
#  138948: 'Enterovirus A',
#  31704: 'Coxsackievirus A16',
#  33757: 'Coxsackievirus A2',
#  39054: 'Enterovirus A71',
#  2760809: 'enterovirus A114',
#  138949: 'Enterovirus B',
#  12072: 'Coxsackievirus B3',
#  138950: 'Enterovirus C',
#  12089: 'Coxsackievirus A24',
#  12080: 'Human poliovirus 1',
#  12083: 'Human poliovirus 2',
#  12086: 'Human poliovirus 3',
#  138951: 'Enterovirus D',
#  42789: 'enterovirus D68',
#  12090: 'enterovirus D70',
#  12064: 'Enterovirus E',
#  1330520: 'Enterovirus F',
#  2849103: 'enterovirus F4',
#  64141: 'Porcine enterovirus 9',
#  310907: 'Enterovirus H',
#  442851: 'Simian enterovirus SV4',
#  1637527: 'Dromedary camel enterovirus 19CC',
#  1330521: 'Enterovirus J',
#  1917412: 'Picornaviridae sp. rodent/Ee/PicoV/NX2015',
#  1826059: 'Enterovirus SEV-gx',
#  147711: 'Rhinovirus A',
#  573824: 'rhinovirus A1',
#  147712: 'Rhinovirus B',
#  12131: 'rhinovirus B14',
#  44130: 'rhinovirus B3',
#  463676: 'Rhinovirus C',
#  992230: 'Human rhinovirus NAT001',
#  1929150: 'Enterovirus AN12',
#  1849328: 'Enterovirus goat/JL14',
#  47681: 'Enterovirus sp.',
#  2220002: 'Sichuan takin enterovirus',
#  1604871: 'Yak enterovirus',
#  47001: 'Equine rhinitis B virus 1',
#  2764087: 'gallivirus A1',
#  1766557: 'Gallivirus Pf-CHK1/GV',
#  1641896: 'Falcovirus A1',
#  12092: 'Hepatovirus A',
#  1708572: 'Phopivirus',
#  1987139: 'Bat hepatovirus SMG18520Minmav2014',
#  1987140: 'Rodent hepatovirus RMU101637Micarv2010',
#  1987141: 'Rodent hepatovirus CIV459Lopsik2004',
#  1987142: 'Rodent hepatovirus KEF121Sigmas2012',
#  1987143: 'Bat hepatovirus BUO2BF86Colafr2010',
#  1987144: 'Hedgehog hepatovirus Igel8Erieur2014',
#  2766976: 'hepatovirus H2',
#  1987145: 'Shrew hepatovirus KS121232Sorara2012',
#  1768064: 'Tupaia hepatovirus A',
#  1431464: 'Bovine hungarovirus 1',
#  1562064: 'Norway rat hunnivirus',
#  1313215: 'Aichi virus 1',
#  194965: 'Aichivirus B',
#  1156769: 'Porcine kobuvirus',
#  569195: 'Porcine kobuvirus swine/S-1-HUN/2007/Hungary',
#  1136133: 'Porcine kobuvirus SH-W-CHN/2010/China',
#  1659220: 'Kobuvirus cattle/Kagoshima-1-22-KoV/2014/JPN',
#  1756444: 'Rabbit picornavirus',
#  2773290: 'rabbit kobuvirus',
#  1836608: 'Canine kobuvirus',
#  1452516: 'Caprine kobuvirus',
#  1659219: 'Kobuvirus cattle/Kagoshima-2-24-KoV/2015/JPN',
#  1074213: 'Mouse kobuvirus M-5/USA/2010',
#  1755590: 'Kunsagivirus A',
#  2169965: 'Kunsagivirus B',
#  2870349: 'kunsagivirus C1',
#  2870351: 'limnipivirus A1',
#  1439369: 'Carp picornavirus 1',
#  1401263: 'Fathead minnow picornavirus',
#  2779843: 'livupivirus A1',
#  2902768: 'megrivirus A2',
#  2902769: 'megrivirus B3CP-APO',
#  1399966: 'pigeon mesivirus 1',
#  2847848: 'megrivirus C2',
#  1987722: 'Harrier picornavirus 1',
#  2079598: 'Penguin megrivirus',
#  1330070: 'Melegrivirus A',
#  980964: 'Turkey hepatitis virus 2993D',
#  1477515: 'Chicken megrivirus',
#  1195365: 'Miniopterus schreibersii picornavirus 1',
#  ...}

# %%
for taxid in virus_host_connection[~virus_host_connection["virus tax id"].isin(taxid_name.keys())]["virus tax id"].unique():
    #print (taxid)

    if taxid not in taxid_name:
        taxid_name[taxid] = virus_host_connection.loc[virus_host_connection["virus tax id"] == taxid]["virus name"].values[0]

# %%
taxid_name[554168]
# Out:
# 'Acanthamoeba castellanii mamavirus'

# %%
desired_rank = ["superkingdom", "clade", "phylum", "class", "order", "family", "genus", "species", "genome"]

parent_son = set()

taxid_taxon = {}

for taxid in taxid_name:
    dict_path = pyphy.getDictPathByTaxid(taxid)
    dict_path["genome"] = taxid
    quartett = [""] * 2
    for rank in desired_rank:
        if rank in dict_path:
            
            name = pyphy.getNameByTaxid(dict_path[rank])

            if rank == "superkingdom":

                quartett[0] = dict_path[rank]

                if dict_path[rank] not in taxid_taxon:
                    taxid_taxon[dict_path[rank]] = [name, rank]
            else:
                quartett[1] = dict_path[rank]

                if quartett[0] != quartett[1]:
                    parent_son.add(tuple(quartett))

                    if dict_path[rank] not in taxid_taxon:
                        taxid_taxon[dict_path[rank]] = [name, rank]

                    quartett[0] = quartett[1]

# %%
with open("brite/taxon.csv", "w") as output:
    output.write(",".join(["taxid", "name", "rank"]) + "\n")

for taxid in taxid_taxon:
    with open("brite/taxon.csv", "a") as output:
        output.write(",".join([f'"{taxid}"', f'"{taxid_taxon[taxid][0]}"', f'"{taxid_taxon[taxid][1]}"']) + "\n")

# %%
with open("brite/taxon_connections.csv", "w") as output:
    output.write(",".join(["from", "to"]) + "\n")

for parent in parent_son:
    with open("brite/taxon_connections.csv", "a") as output:
        #["~id", "~from", "~to", "~label"]
        output.write(",".join([f'"{parent[0]}"', f'"{parent[1]}"']) + "\n")

# %%
pyphy.getDictPathByTaxid(259931)
# Out:
# {'no rank': 1,
#  'species': 12639,
#  'genus': 10437,
#  'family': 10404,
#  'order': 2732515,
#  'class': 2732514,
#  'phylum': 2732409,
#  'kingdom': 2732397,
#  'clade': 2559587,
#  'superkingdom': 10239}
